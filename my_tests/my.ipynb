# %%
import sys
import os

# Adjust path to reach the directory where AzWrap is located
sys.path.append(os.path.abspath("../"))  # or "../../" depending on how far it is

from AzWrap.wrapper import (
    Identity,
    Subscription,
    ResourceGroup,
    StorageAccount,
    SearchService,
    SearchIndex,
    AIService,
    OpenAIClient
)

# %%
from dotenv import load_dotenv
load_dotenv(

)
import os

tenant = os.getenv("AZURE_TENANT_ID")
client = os.getenv("AZURE_CLIENT_ID")
secret = os.getenv("AZURE_CLIENT_SECRET")
su = os.getenv("AZURE_SUBSCRIPTION_ID")

# %%
id = Identity(tenant_id=tenant , client_id=client , client_secret=secret)

# %%
sub = id.get_subscription(su)

# %%
rg = sub.get_resource_group('AI_RG')

# %%
# %pip install pynput
# Out:
# ...
#   Using cached pynput-1.8.1-py2.py3-none-any.whl.metadata (32 kB)
# ...
# Using cached pynput-1.8.1-py2.py3-none-any.whl (91 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pynput.mouse import Controller, Button
import time

mouse = Controller()

while True:
    mouse.click(Button.left)  # Simulate a left mouse button click
    time.sleep(15)  # Sleep for 60 seconds
    print("CLICK")
# Out:
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# CLICK
# ...
